# %%
import torch
import numpy as np
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
model_name = "gpt2-large"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1280)
#     (wpe): Embedding(1024, 1280)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-35): 36 x GPT2Block(
#         (ln_1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D(nf=3840, nx=1280)
#           (c_proj): Conv1D(nf=1280, nx=1280)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=5120, nx=1280)
#           (c_proj): Conv1D(nf=1280, nx=5120)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1280, out_features=50257, bias=False)
# )

# %%
"""
    ! Saving and loading, model and tokenizer
"""
def save_models(model = model, tokenizer = tokenizer, path = "../models/gpt2-large"):
    model.save_pretrained("../models/gpt2-large")
    tokenizer.save_pretrained("../models/gpt2-large")
    
def load_model(path = "../models/gpt2-large"):
    model = GPT2LMHeadModel.from_pretrained(path).to(device)
    tokenizer = GPT2Tokenizer.from_pretrained(path)
    return model, tokenizer

# %%
prompt = "The developer argued with the designer because her"
inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)

outputs = model.generate(
    inputs,
    max_length=100,        # Adjust length as needed
    num_return_sequences=1, # Number of generated sequences
    no_repeat_ngram_size=2, # Avoid repeating phrases
    do_sample=True,        # Use sampling instead of greedy decoding
    top_k=50,              # Top-k sampling
    top_p=0.95,            # Nucleus sampling
    temperature=0.7        # Controls randomness: lower is less random
)

generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The developer argued with the designer because her design was not compatible with his vision for the project.
#
# "As the architect, the developer has the right to approve the design," the judge said. "In this case, it was the defendant's design that was rejected."
#  alderman@chicagotribune.com
# .

# %%
"""
    ! These are the pronouns present in the WinoBias dataset
"""

pronouns = ["he", "she", "him", "her", "his"]

opposite = {
    "he": "she",
    "she": "he",
    "him": "her",
    "her": "him",
    "his": "her",
}

# %%
import math

def compute_logprob(text):
    input_ids = tokenizer.encode(text, return_tensors='pt').to(device)
    
    with torch.no_grad():
        outputs = model(input_ids, labels=input_ids)
    
    loss = outputs.loss.item()
    n_tokens = input_ids.shape[-1]
    total_neg_log_likelihood = loss * n_tokens
    print(f"Negative log likelihood: {-total_neg_log_likelihood}")
    return -total_neg_log_likelihood

# %%
import json
import re
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_winobias(file_path):
    y_true = []
    y_pred = []
    correct_count = 0
    total_count = 0
    
    if file_path[0] == 'a':
        # Anti
        correct_label = 0
        pass
    
    else:
        # Stereotypical
        correct_label = 1
        pass
        
    
    with open(file_path, "r") as f:
        for line in f:
            data = line.split("\t")
            index = data[0]
            text = data[1]
            label = data[2]

            """
                Identify the entities in the model
            """
            identity_1 = str(text.split(" ")[1])
            pattern = r'\[(.*?)\]'
            matches = re.findall(pattern, text)
            identity_2 = str(matches[0].split(" ")[1])
            pronoun_in_the_text = str(matches[1])
            # print(identity_1)
            # print(matches)
            # print(identity_2)
            # print(pronoun_in_the_text)
            # print(correct_label)
            
            
            changed_text = text.replace(pronoun_in_the_text, opposite[pronoun_in_the_text])
            
            lp1 = compute_logprob(text)
            lp2 = compute_logprob(changed_text)
            
            predicted_label = "changed" if lp2 > lp1 else "same"
            
            
            if correct_label == 0 and predicted_label == "same":
                correct_count += 1
                y_pred.append(correct_label)
            
            if correct_label == 1 and predicted_label == "changed":
                correct_count += 1
                y_pred.append(correct_label)
                
            else:
                y_pred.append(abs(correct_label - 1))
            
            y_true.append(correct_label)
            
            total_count += 1
        
        
        acc = accuracy_score(y_true, y_pred)
        prec = precision_score(y_true, y_pred, pos_label=1)
        rec = recall_score(y_true, y_pred, pos_label=1)
        f1 = f1_score(y_true, y_pred, pos_label=1)
        
        accuracy = correct_count/total_count
        print("Correct count: ", correct_count)
        print("Total Count: ", total_count)
        print(f"Accuracy__: {accuracy:.6f}")
        
        print(f"File: {file_path}")
        print(f"Total samples: {len(y_true)}")
        print(f"Accuracy: {acc:.4f}")
        print(f"Precision (pred=1): {prec:.4f}")
        print(f"Recall   (pred=1): {rec:.4f}")
        print(f"F1       (pred=1): {f1:.4f}")

            


evaluate_winobias("../data/WinoBias/new/pro_stereotyped_type2.dev.tsv")
# Out:
# Negative log likelihood: -67.9595377445221
# Negative log likelihood: -66.6952006816864
# Negative log likelihood: -64.01534938812256
# Negative log likelihood: -65.9453296661377
# Negative log likelihood: -73.0727014541626
# Negative log likelihood: -73.75556230545044
# Negative log likelihood: -72.68545055389404
# Negative log likelihood: -73.69480609893799
# Negative log likelihood: -76.6099214553833
# Negative log likelihood: -78.53764533996582
# Negative log likelihood: -74.42144393920898
# Negative log likelihood: -73.75554084777832
# Negative log likelihood: -92.29892492294312
# Negative log likelihood: -93.54673671722412
# Negative log likelihood: -82.68440771102905
# Negative log likelihood: -80.40899419784546
# Negative log likelihood: -67.64164733886719
# Negative log likelihood: -69.3625717163086
# Negative log likelihood: -86.05631828308105
# Negative log likelihood: -87.14844703674316
# Negative log likelihood: -77.8641128540039
# Negative log likelihood: -78.54316234588623
# Negative log likelihood: -72.24133014678955
# Negative log likelihood: -74.70545768737793
# Negative log likelihood: -69.480384349823
# Negative log likelihood: -68.88210582733154
# Negative log likelihood: -67.58137321472168
# Negative log likelihood: -70.36608481407166
# Negative log likelihood: -82.37231636047363
# Negative log likelihood: -104.59706211090088
# Negative log likelihood: -79.14856338500977
# Negative log likelihood: -79.24424743652344
# Negative log likelihood: -72.56601047515869
# Negative log likelihood: -73.06923580169678
# Negative log likelihood: -77.82573223114014
# Negative log likelihood: -78.00991630554199
# Negative log likelihood: -66.37815713882446
# Negative log likelihood: -65.52225351333618
# Negative log likelihood: -78.61306571960449
# Negative log likelihood: -79.7457389831543
# Negative log likelihood: -75.88983535766602
# Negative log likelihood: -77.97626495361328
# Negative log likelihood: -77.60798454284668
# Negative log likelihood: -79.02261734008789
# Negative log likelihood: -73.92540550231934
# Negative log likelihood: -75.57541465759277
# Negative log likelihood: -71.46188879013062
# Negative log likelihood: -71.7192907333374
# Negative log likelihood: -79.21771430969238
# Negative log likelihood: -79.55575776100159
# Negative log likelihood: -75.25793409347534
# Negative log likelihood: -75.81989622116089
# Negative log likelihood: -75.27515745162964
# Negative log likelihood: -75.17603302001953
# Negative log likelihood: -73.01880168914795
# Negative log likelihood: -74.56735706329346
# Negative log likelihood: -60.32993793487549
# Negative log likelihood: -60.01389026641846
# Negative log likelihood: -60.038819313049316
# Negative log likelihood: -62.60424041748047
# Negative log likelihood: -68.80232238769531
# Negative log likelihood: -69.23554992675781
# Negative log likelihood: -73.40638637542725
# Negative log likelihood: -71.85169219970703
# Negative log likelihood: -66.74409294128418
# Negative log likelihood: -71.0468864440918
# Negative log likelihood: -78.18396759033203
# Negative log likelihood: -76.11772155761719
# Negative log likelihood: -78.23209285736084
# Negative log likelihood: -79.43159580230713
# Negative log likelihood: -62.11899518966675
# Negative log likelihood: -65.06610774993896
# Negative log likelihood: -74.34372615814209
# Negative log likelihood: -72.58329582214355
# Negative log likelihood: -66.55104637145996
# Negative log likelihood: -68.57054710388184
# Negative log likelihood: -76.82952880859375
# Negative log likelihood: -77.12624073028564
# Negative log likelihood: -79.8760986328125
# Negative log likelihood: -81.73413276672363
# Negative log likelihood: -87.37229299545288
# Negative log likelihood: -89.41845464706421
# Negative log likelihood: -91.79335498809814
# Negative log likelihood: -91.62501287460327
# Negative log likelihood: -60.19660568237305
# Negative log likelihood: -63.401023864746094
# Negative log likelihood: -61.13959503173828
# Negative log likelihood: -58.963314056396484
# Negative log likelihood: -75.69572925567627
# Negative log likelihood: -75.2757740020752
# Negative log likelihood: -85.74398040771484
# Negative log likelihood: -87.05796241760254
# Negative log likelihood: -67.0042142868042
# Negative log likelihood: -63.28766107559204
# Negative log likelihood: -57.948116302490234
# Negative log likelihood: -61.495872497558594
# Negative log likelihood: -88.76666688919067
# Negative log likelihood: -86.4136643409729
# Negative log likelihood: -96.94955205917358
# Negative log likelihood: -98.68685817718506
# Negative log likelihood: -55.341514348983765
# Negative log likelihood: -55.2388858795166
# Negative log likelihood: -71.56517791748047
# Negative log likelihood: -71.29570770263672
# Negative log likelihood: -76.31863117218018
# Negative log likelihood: -73.16698551177979
# Negative log likelihood: -67.04496383666992
# Negative log likelihood: -69.94420051574707
# Negative log likelihood: -75.23208332061768
# Negative log likelihood: -75.76349544525146
# Negative log likelihood: -76.5659351348877
# Negative log likelihood: -77.89590740203857
# Negative log likelihood: -67.6466417312622
# Negative log likelihood: -67.89568376541138
# Negative log likelihood: -68.78746032714844
# Negative log likelihood: -69.79203987121582
# Negative log likelihood: -58.94245147705078
# Negative log likelihood: -60.307936668395996
# Negative log likelihood: -58.490633726119995
# Negative log likelihood: -58.04044437408447
# Negative log likelihood: -83.37556076049805
# Negative log likelihood: -80.49538946151733
# Negative log likelihood: -79.45033836364746
# Negative log likelihood: -82.77960014343262
# Negative log likelihood: -74.38633704185486
# Negative log likelihood: -70.41927194595337
# Negative log likelihood: -70.90761995315552
# Negative log likelihood: -74.31563472747803
# Negative log likelihood: -69.81151485443115
# Negative log likelihood: -66.8611192703247
# Negative log likelihood: -76.36617279052734
# Negative log likelihood: -79.26462364196777
# Negative log likelihood: -65.03749084472656
# Negative log likelihood: -67.60348510742188
# Negative log likelihood: -67.86950445175171
# Negative log likelihood: -68.97630786895752
# Negative log likelihood: -78.59567642211914
# Negative log likelihood: -77.28000164031982
# Negative log likelihood: -69.06645965576172
# Negative log likelihood: -71.70756530761719
# Negative log likelihood: -69.4659194946289
# Negative log likelihood: -71.48184967041016
# Negative log likelihood: -73.50154876708984
# Negative log likelihood: -72.06354522705078
# Negative log likelihood: -69.30562734603882
# Negative log likelihood: -68.06504487991333
# Negative log likelihood: -72.96532559394836
# Negative log likelihood: -74.690349817276
# Negative log likelihood: -56.33076858520508
# Negative log likelihood: -60.218936920166016
# Negative log likelihood: -72.05583143234253
# Negative log likelihood: -69.41066908836365
# Negative log likelihood: -66.0880479812622
# Negative log likelihood: -66.71532440185547
# Negative log likelihood: -57.00521945953369
# Negative log likelihood: -59.994096755981445
# Negative log likelihood: -71.16041564941406
# Negative log likelihood: -70.3270673751831
# Negative log likelihood: -77.23677921295166
# Negative log likelihood: -79.68627548217773
# Negative log likelihood: -58.70454025268555
# Negative log likelihood: -63.245784759521484
# Negative log likelihood: -63.93435597419739
# Negative log likelihood: -61.30942440032959
# Negative log likelihood: -78.74741554260254
# Negative log likelihood: -77.86669254302979
# Negative log likelihood: -85.089026927948
# Negative log likelihood: -85.60459613800049
# Negative log likelihood: -70.94951725006104
# Negative log likelihood: -68.29456424713135
# Negative log likelihood: -69.57867240905762
# Negative log likelihood: -72.2393159866333
# Negative log likelihood: -78.00999355316162
# Negative log likelihood: -76.75499439239502
# Negative log likelihood: -75.73197174072266
# Negative log likelihood: -76.61228656768799
# Negative log likelihood: -84.34269666671753
# Negative log likelihood: -84.52408504486084
# Negative log likelihood: -84.76065731048584
# Negative log likelihood: -84.46153545379639
# Negative log likelihood: -72.75026607513428
# Negative log likelihood: -71.35176086425781
# Negative log likelihood: -73.91689658164978
# Negative log likelihood: -78.41801643371582
# Negative log likelihood: -82.3978590965271
# Negative log likelihood: -81.50707340240479
# Negative log likelihood: -70.56644916534424
# Negative log likelihood: -71.31441116333008
# Negative log likelihood: -57.19001579284668
# Negative log likelihood: -61.048776626586914
# Negative log likelihood: -56.76633143424988
# Negative log likelihood: -54.63795518875122
# Negative log likelihood: -71.16731548309326
# Negative log likelihood: -71.65946102142334
# Negative log likelihood: -72.0786828994751
# Negative log likelihood: -73.81404876708984
# Negative log likelihood: -80.96112298965454
# Negative log likelihood: -79.59491634368896
# Negative log likelihood: -65.71136689186096
# Negative log likelihood: -70.04356479644775
# Negative log likelihood: -67.70992279052734
# Negative log likelihood: -69.509765625
# Negative log likelihood: -78.43642473220825
# Negative log likelihood: -80.3672399520874
# Negative log likelihood: -80.18343257904053
# Negative log likelihood: -78.91874313354492
# Negative log likelihood: -88.57291412353516
# Negative log likelihood: -88.11991882324219
# Negative log likelihood: -71.69378137588501
# Negative log likelihood: -89.60639953613281
# Negative log likelihood: -58.45732378959656
# Negative log likelihood: -62.978392124176025
# Negative log likelihood: -73.27414131164551
# Negative log likelihood: -71.72394609451294
# Negative log likelihood: -66.3300392627716
# Negative log likelihood: -68.77937364578247
# Negative log likelihood: -87.7091703414917
# Negative log likelihood: -86.82517147064209
# Negative log likelihood: -69.78646874427795
# Negative log likelihood: -74.38832473754883
# Negative log likelihood: -65.24998927116394
# Negative log likelihood: -69.32403945922852
# Negative log likelihood: -75.87809658050537
# Negative log likelihood: -74.01411151885986
# Negative log likelihood: -73.41511821746826
# Negative log likelihood: -74.38176918029785
# Negative log likelihood: -77.54840469360352
# Negative log likelihood: -81.2994031906128
# Negative log likelihood: -85.56487941741943
# Negative log likelihood: -83.03419589996338
# Negative log likelihood: -79.7358341217041
# Negative log likelihood: -83.4777946472168
# Negative log likelihood: -70.38089752197266
# Negative log likelihood: -71.75265502929688
# Negative log likelihood: -56.89606475830078
# Negative log likelihood: -57.74203872680664
# Negative log likelihood: -102.8766393661499
# Negative log likelihood: -102.34233093261719
# Negative log likelihood: -65.39102959632874
# Negative log likelihood: -67.32476305961609
# Negative log likelihood: -67.85272979736328
# Negative log likelihood: -67.08212280273438
# Negative log likelihood: -67.01250457763672
# Negative log likelihood: -69.1731185913086
# Negative log likelihood: -81.33822011947632
# Negative log likelihood: -81.58603620529175
# Negative log likelihood: -80.08744382858276
# Negative log likelihood: -81.00867819786072
# Negative log likelihood: -71.40313339233398
# Negative log likelihood: -71.71141576766968
# Negative log likelihood: -74.59000968933105
# Negative log likelihood: -73.1019115447998
# Negative log likelihood: -67.60482501983643
# Negative log likelihood: -66.23892593383789
# Negative log likelihood: -68.77042579650879
# Negative log likelihood: -70.35763835906982
# Negative log likelihood: -59.49171781539917
# Negative log likelihood: -61.90577745437622
# Negative log likelihood: -55.68894624710083
# Negative log likelihood: -54.41709637641907
# Negative log likelihood: -70.73287963867188
# Negative log likelihood: -73.75696563720703
# Negative log likelihood: -68.83541822433472
# Negative log likelihood: -70.38011312484741
# Negative log likelihood: -61.07808470726013
# Negative log likelihood: -78.94252681732178
# Negative log likelihood: -61.609363079071045
# Negative log likelihood: -66.02258610725403
# Negative log likelihood: -76.78157043457031
# Negative log likelihood: -81.1820182800293
# Negative log likelihood: -79.77810430526733
# Negative log likelihood: -77.11722564697266
# Negative log likelihood: -71.20476579666138
# Negative log likelihood: -68.58688688278198
# Negative log likelihood: -64.05892753601074
# Negative log likelihood: -67.94017839431763
# Negative log likelihood: -89.3667984008789
# Negative log likelihood: -86.93957328796387
# Negative log likelihood: -74.07341480255127
# Negative log likelihood: -77.66762256622314
# Negative log likelihood: -63.795082569122314
# Negative log likelihood: -81.9357795715332
# Negative log likelihood: -55.204174518585205
# Negative log likelihood: -58.47200274467468
# Negative log likelihood: -69.29817867279053
# Negative log likelihood: -71.40845918655396
# Negative log likelihood: -73.08774089813232
# Negative log likelihood: -72.95184516906738
# Negative log likelihood: -70.12549209594727
# Negative log likelihood: -69.55947732925415
# Negative log likelihood: -70.5302402973175
# Negative log likelihood: -71.4870388507843
# Negative log likelihood: -83.53805112838745
# Negative log likelihood: -82.00623273849487
# Negative log likelihood: -81.60955381393433
# Negative log likelihood: -83.5546145439148
# Negative log likelihood: -63.56592559814453
# Negative log likelihood: -61.187156677246094
# Negative log likelihood: -59.87157440185547
# Negative log likelihood: -63.766414642333984
# Negative log likelihood: -59.36173439025879
# Negative log likelihood: -61.1877179145813
# Negative log likelihood: -59.49037170410156
# Negative log likelihood: -59.69825744628906
# Negative log likelihood: -73.4014892578125
# Negative log likelihood: -75.90701293945312
# Negative log likelihood: -67.4966812133789
# Negative log likelihood: -66.1288070678711
# Negative log likelihood: -67.20449209213257
# Negative log likelihood: -64.6643328666687
# Negative log likelihood: -63.438499450683594
# Negative log likelihood: -65.78801727294922
# Negative log likelihood: -75.05691766738892
# Negative log likelihood: -75.93109464645386
# Negative log likelihood: -62.83510208129883
# Negative log likelihood: -66.15690612792969
# Negative log likelihood: -71.05517387390137
# Negative log likelihood: -70.24035167694092
# Negative log likelihood: -74.69821643829346
# Negative log likelihood: -76.76816082000732
# Negative log likelihood: -80.84114646911621
# Negative log likelihood: -82.45521879196167
# Negative log likelihood: -79.09426164627075
# Negative log likelihood: -80.73573303222656
# Negative log likelihood: -74.67745399475098
# Negative log likelihood: -73.47813320159912
# Negative log likelihood: -73.13888883590698
# Negative log likelihood: -120.10719299316406
# Negative log likelihood: -70.2266845703125
# Negative log likelihood: -69.47393989562988
# Negative log likelihood: -73.64287757873535
# Negative log likelihood: -74.99108982086182
# Negative log likelihood: -74.86538648605347
# Negative log likelihood: -74.33944606781006
# Negative log likelihood: -76.06258964538574
# Negative log likelihood: -78.55416870117188
# Negative log likelihood: -87.13870525360107
# Negative log likelihood: -86.55026721954346
# Negative log likelihood: -80.14739227294922
# Negative log likelihood: -80.39403533935547
# Negative log likelihood: -91.30415630340576
# Negative log likelihood: -92.95612144470215
# Negative log likelihood: -86.26282024383545
# Negative log likelihood: -88.01378345489502
# Negative log likelihood: -60.986915588378906
# Negative log likelihood: -61.503849029541016
# Negative log likelihood: -67.73789882659912
# Negative log likelihood: -67.86478424072266
# Negative log likelihood: -88.27107238769531
# Negative log likelihood: -106.98480224609375
# Negative log likelihood: -85.26810264587402
# Negative log likelihood: -85.45117950439453
# Negative log likelihood: -71.67697191238403
# Negative log likelihood: -68.31499814987183
# Negative log likelihood: -68.64701128005981
# Negative log likelihood: -71.43461608886719
# Negative log likelihood: -68.69725441932678
# Negative log likelihood: -69.99447226524353
# Negative log likelihood: -69.57633471488953
# Negative log likelihood: -70.9408311843872
# Negative log likelihood: -87.46806240081787
# Negative log likelihood: -87.38809394836426
# Negative log likelihood: -83.43406963348389
# Negative log likelihood: -85.47976970672607
# Negative log likelihood: -73.26353788375854
# Negative log likelihood: -91.93971252441406
# Negative log likelihood: -80.23167276382446
# Negative log likelihood: -80.79360771179199
# Negative log likelihood: -82.81352591514587
# Negative log likelihood: -81.20549011230469
# Negative log likelihood: -71.01323223114014
# Negative log likelihood: -73.74293279647827
# Negative log likelihood: -84.85570192337036
# Negative log likelihood: -92.69674873352051
# Negative log likelihood: -90.14626598358154
# Negative log likelihood: -98.67197513580322
# Negative log likelihood: -80.54316139221191
# Negative log likelihood: -78.3715181350708
# Negative log likelihood: -84.68474578857422
# Negative log likelihood: -85.7117190361023
# Negative log likelihood: -84.17194032669067
# Negative log likelihood: -81.04255485534668
# Negative log likelihood: -143.41706085205078
# Negative log likelihood: -72.47732543945312
# Negative log likelihood: -72.55245208740234
# Negative log likelihood: -62.570677757263184
# Negative log likelihood: -66.01414775848389
# Negative log likelihood: -74.16605043411255
# Negative log likelihood: -73.6587233543396
# Negative log likelihood: -80.81584739685059
# Negative log likelihood: -81.8660535812378
# Negative log likelihood: -94.63667058944702
# Negative log likelihood: -92.51771259307861
# Negative log likelihood: -98.18639755249023
# Negative log likelihood: -98.85237693786621
# Negative log likelihood: -72.903076171875
# Negative log likelihood: -97.89357995986938
# Negative log likelihood: -81.40243816375732
# Negative log likelihood: -81.90643501281738
# Negative log likelihood: -99.26998138427734
# Negative log likelihood: -99.9188232421875
# Negative log likelihood: -111.44499206542969
# Negative log likelihood: -115.3579330444336
# Negative log likelihood: -96.35864639282227
# Negative log likelihood: -95.003173828125
# Negative log likelihood: -80.36121368408203
# Negative log likelihood: -83.1766357421875
# Negative log likelihood: -70.99800062179565
# Negative log likelihood: -70.77828121185303
# Negative log likelihood: -80.32812595367432
# Negative log likelihood: -82.75792407989502
# Negative log likelihood: -95.88521671295166
# Negative log likelihood: -101.40563106536865
# Negative log likelihood: -84.88910675048828
# Negative log likelihood: -87.56460189819336
# Negative log likelihood: -67.12504434585571
# Negative log likelihood: -68.24773979187012
# Negative log likelihood: -63.817344188690186
# Negative log likelihood: -67.11325550079346
# Negative log likelihood: -66.81466221809387
# Negative log likelihood: -86.16250133514404
# Negative log likelihood: -70.7816162109375
# Negative log likelihood: -72.51966190338135
# Negative log likelihood: -59.58991885185242
# Negative log likelihood: -57.78916597366333
# Negative log likelihood: -100.64592552185059
# Negative log likelihood: -103.4022159576416
# Negative log likelihood: -96.1919059753418
# Negative log likelihood: -103.37836074829102
# Negative log likelihood: -79.43272304534912
# Negative log likelihood: -82.68446159362793
# Negative log likelihood: -86.10768413543701
# Negative log likelihood: -85.20601177215576
# Negative log likelihood: -89.25334692001343
# Negative log likelihood: -89.86161994934082
# Negative log likelihood: -67.86509799957275
# Negative log likelihood: -66.01422119140625
# Negative log likelihood: -77.12037658691406
# Negative log likelihood: -79.3329086303711
# Negative log likelihood: -80.32975673675537
# Negative log likelihood: -80.495924949646
# Negative log likelihood: -86.55917263031006
# Negative log likelihood: -87.65121459960938
# Negative log likelihood: -82.99318313598633
# Negative log likelihood: -83.99235725402832
# Negative log likelihood: -67.85394430160522
# Negative log likelihood: -72.5775933265686
# Negative log likelihood: -63.189612865448
# Negative log likelihood: -63.34513807296753
# Negative log likelihood: -70.58582282066345
# Negative log likelihood: -72.38519310951233
# Negative log likelihood: -92.85048580169678
# Negative log likelihood: -91.4854621887207
# Negative log likelihood: -83.18264770507812
# Negative log likelihood: -84.14782428741455
# Negative log likelihood: -80.12031841278076
# Negative log likelihood: -78.87846803665161
# Negative log likelihood: -74.57349514961243
# Negative log likelihood: -75.50064969062805
# Negative log likelihood: -98.82725715637207
# Negative log likelihood: -97.04809856414795
# Negative log likelihood: -110.83960485458374
# Negative log likelihood: -112.23998069763184
# Negative log likelihood: -78.29930305480957
# Negative log likelihood: -77.78059387207031
# Negative log likelihood: -79.96118068695068
# Negative log likelihood: -82.60823249816895
# Negative log likelihood: -82.86675453186035
# Negative log likelihood: -83.95183563232422
# Negative log likelihood: -78.65387916564941
# Negative log likelihood: -80.909423828125
# Negative log likelihood: -79.52653455734253
# Negative log likelihood: -89.25223731994629
# Negative log likelihood: -61.876670837402344
# Negative log likelihood: -63.80556678771973
# Negative log likelihood: -67.71828007698059
# Negative log likelihood: -66.14452815055847
# Negative log likelihood: -74.96667766571045
# Negative log likelihood: -78.02559757232666
# Negative log likelihood: -99.1339521408081
# Negative log likelihood: -98.97413063049316
# Negative log likelihood: -102.46170043945312
# Negative log likelihood: -102.27812576293945
# Negative log likelihood: -106.8167142868042
# Negative log likelihood: -132.39468383789062
# Negative log likelihood: -93.15236854553223
# Negative log likelihood: -95.5935411453247
# Negative log likelihood: -87.76044464111328
# Negative log likelihood: -88.33422088623047
# Negative log likelihood: -71.09917068481445
# Negative log likelihood: -76.02269506454468
# Negative log likelihood: -92.47544288635254
# Negative log likelihood: -92.83202648162842
# Negative log likelihood: -87.63012313842773
# Negative log likelihood: -136.15961074829102
# Negative log likelihood: -69.24002933502197
# Negative log likelihood: -73.31191158294678
# Negative log likelihood: -68.92493724822998
# Negative log likelihood: -70.43198299407959
# Negative log likelihood: -82.71354961395264
# Negative log likelihood: -82.23711204528809
# Negative log likelihood: -75.3341293334961
# Negative log likelihood: -77.43085479736328
# Negative log likelihood: -87.50011444091797
# Negative log likelihood: -89.60182189941406
# Negative log likelihood: -71.884521484375
# Negative log likelihood: -71.28324890136719
# Negative log likelihood: -77.60853338241577
# Negative log likelihood: -78.94416809082031
# Negative log likelihood: -75.96947145462036
# Negative log likelihood: -77.21749877929688
# Negative log likelihood: -79.3578052520752
# Negative log likelihood: -81.36478996276855
# Negative log likelihood: -84.4125394821167
# Negative log likelihood: -84.8134412765503
# Negative log likelihood: -83.80324268341064
# Negative log likelihood: -82.65218162536621
# Negative log likelihood: -80.93250274658203
# Negative log likelihood: -82.91678810119629
# Negative log likelihood: -74.74296975135803
# Negative log likelihood: -73.89102149009705
# Negative log likelihood: -70.8332290649414
# Negative log likelihood: -73.82272338867188
# Negative log likelihood: -84.67642736434937
# Negative log likelihood: -86.17484951019287
# Negative log likelihood: -101.10764122009277
# Negative log likelihood: -102.37591123580933
# Negative log likelihood: -89.78314304351807
# Negative log likelihood: -88.89941453933716
# Negative log likelihood: -88.04783463478088
# Negative log likelihood: -133.33255863189697
# Negative log likelihood: -90.54244041442871
# Negative log likelihood: -91.12866401672363
# Negative log likelihood: -90.98633861541748
# Negative log likelihood: -92.7110366821289
# Negative log likelihood: -72.47045135498047
# Negative log likelihood: -88.48940563201904
# Negative log likelihood: -79.06112480163574
# Negative log likelihood: -81.01775646209717
# Negative log likelihood: -80.7431173324585
# Negative log likelihood: -79.62682914733887
# Negative log likelihood: -81.45822191238403
# Negative log likelihood: -84.64351272583008
# Negative log likelihood: -75.70458984375
# Negative log likelihood: -74.33425998687744
# Negative log likelihood: -86.73455715179443
# Negative log likelihood: -89.42232322692871
# Negative log likelihood: -61.10859298706055
# Negative log likelihood: -68.77635192871094
# Negative log likelihood: -71.88446569442749
# Negative log likelihood: -74.32444953918457
# Negative log likelihood: -67.6748628616333
# Negative log likelihood: -69.52109813690186
# Negative log likelihood: -74.62640285491943
# Negative log likelihood: -71.96491241455078
# Negative log likelihood: -78.35638904571533
# Negative log likelihood: -79.25301933288574
# Negative log likelihood: -79.43416404724121
# Negative log likelihood: -86.31907844543457
# Negative log likelihood: -70.93900728225708
# Negative log likelihood: -73.04621839523315
# Negative log likelihood: -70.13443565368652
# Negative log likelihood: -67.33994197845459
# Negative log likelihood: -63.756794929504395
# Negative log likelihood: -66.32266521453857
# Negative log likelihood: -63.038039207458496
# Negative log likelihood: -62.612361907958984
# Negative log likelihood: -73.41077327728271
# Negative log likelihood: -71.98772192001343
# Negative log likelihood: -73.4901237487793
# Negative log likelihood: -75.5159854888916
# Negative log likelihood: -69.0387191772461
# Negative log likelihood: -74.4598159790039
# Negative log likelihood: -77.760498046875
# Negative log likelihood: -91.33972263336182
# Negative log likelihood: -71.14332103729248
# Negative log likelihood: -71.91391563415527
# Negative log likelihood: -71.68610620498657
# Negative log likelihood: -72.50030422210693
# Negative log likelihood: -57.571470737457275
# Negative log likelihood: -61.02522611618042
# Negative log likelihood: -65.82160234451294
# Negative log likelihood: -84.69708633422852
# Negative log likelihood: -73.30004072189331
# Negative log likelihood: -73.72351026535034
# Negative log likelihood: -74.43847990036011
# Negative log likelihood: -73.55607604980469
# Negative log likelihood: -75.75871467590332
# Negative log likelihood: -77.0085039138794
# Negative log likelihood: -73.72892189025879
# Negative log likelihood: -72.62163734436035
# Negative log likelihood: -78.17681789398193
# Negative log likelihood: -79.26431655883789
# Negative log likelihood: -103.00577545166016
# Negative log likelihood: -102.83668613433838
# Negative log likelihood: -69.82399463653564
# Negative log likelihood: -71.17284965515137
# Negative log likelihood: -80.42922019958496
# Negative log likelihood: -95.53403949737549
# Negative log likelihood: -62.877140045166016
# Negative log likelihood: -66.46172332763672
# Negative log likelihood: -63.51103973388672
# Negative log likelihood: -83.31776237487793
# Negative log likelihood: -77.02336311340332
# Negative log likelihood: -77.77026653289795
# Negative log likelihood: -81.32994651794434
# Negative log likelihood: -80.14607429504395
# Negative log likelihood: -63.0478515625
# Negative log likelihood: -66.06967163085938
# Negative log likelihood: -65.53401184082031
# Negative log likelihood: -62.88959503173828
# Negative log likelihood: -74.45784568786621
# Negative log likelihood: -77.021409034729
# Negative log likelihood: -62.108867168426514
# Negative log likelihood: -60.69282817840576
# Negative log likelihood: -63.254239082336426
# Negative log likelihood: -68.66219806671143
# Negative log likelihood: -65.8483304977417
# Negative log likelihood: -85.19664716720581
# Negative log likelihood: -80.81792831420898
# Negative log likelihood: -100.06151247024536
# Negative log likelihood: -75.7474913597107
# Negative log likelihood: -76.2695140838623
# Negative log likelihood: -60.53019714355469
# Negative log likelihood: -63.34571075439453
# Negative log likelihood: -57.848093032836914
# Negative log likelihood: -57.27592372894287
# Negative log likelihood: -63.05150604248047
# Negative log likelihood: -67.36907196044922
# Negative log likelihood: -67.07720184326172
# Negative log likelihood: -63.72823715209961
# Negative log likelihood: -56.88137865066528
# Negative log likelihood: -58.88164043426514
# Negative log likelihood: -56.99093770980835
# Negative log likelihood: -56.164775371551514
# Negative log likelihood: -68.14520692825317
# Negative log likelihood: -69.656240940094
# Negative log likelihood: -88.59461688995361
# Negative log likelihood: -87.28240299224854
# Negative log likelihood: -56.702178716659546
# Negative log likelihood: -59.07218956947327
# Negative log likelihood: -61.14828109741211
# Negative log likelihood: -62.64462947845459
# Negative log likelihood: -56.53536939620972
# Negative log likelihood: -56.35429382324219
# Negative log likelihood: -69.533034324646
# Negative log likelihood: -70.59528303146362
# Negative log likelihood: -66.2758469581604
# Negative log likelihood: -71.37032747268677
# Negative log likelihood: -61.33239269256592
# Negative log likelihood: -63.52588891983032
# Negative log likelihood: -72.43025827407837
# Negative log likelihood: -75.63628101348877
# Negative log likelihood: -78.20569705963135
# Negative log likelihood: -97.49639225006104
# Negative log likelihood: -64.47194051742554
# Negative log likelihood: -67.51756954193115
# Negative log likelihood: -75.53565502166748
# Negative log likelihood: -71.32055282592773
# Negative log likelihood: -78.0258584022522
# Negative log likelihood: -78.88341474533081
# Negative log likelihood: -59.347785234451294
# Negative log likelihood: -79.6594591140747
# Negative log likelihood: -73.21848392486572
# Negative log likelihood: -79.84561443328857
# Negative log likelihood: -78.94276142120361
# Negative log likelihood: -72.6166319847107
# Negative log likelihood: -75.12501382827759
# Negative log likelihood: -76.81348371505737
# Negative log likelihood: -76.31271958351135
# Negative log likelihood: -76.2323706150055
# Negative log likelihood: -65.12859344482422
# Negative log likelihood: -67.44296264648438
# Negative log likelihood: -70.48969268798828
# Negative log likelihood: -67.20556735992432
# Negative log likelihood: -88.43954849243164
# Negative log likelihood: -91.46469116210938
# Negative log likelihood: -89.70562934875488
# Negative log likelihood: -87.68930435180664
# Negative log likelihood: -61.577489376068115
# Negative log likelihood: -65.04206228256226
# Negative log likelihood: -66.38668155670166
# Negative log likelihood: -65.41386079788208
# Negative log likelihood: -73.5161361694336
# Negative log likelihood: -75.63776397705078
# Negative log likelihood: -79.33715057373047
# Negative log likelihood: -78.40582752227783
# Negative log likelihood: -76.87600231170654
# Negative log likelihood: -79.88165330886841
# Negative log likelihood: -78.39608240127563
# Negative log likelihood: -75.61428356170654
# Negative log likelihood: -65.76274085044861
# Negative log likelihood: -68.34614419937134
# Negative log likelihood: -61.51661157608032
# Negative log likelihood: -60.49971318244934
# Negative log likelihood: -69.72929763793945
# Negative log likelihood: -72.65509414672852
# Negative log likelihood: -63.85999345779419
# Negative log likelihood: -62.87622785568237
# Negative log likelihood: -80.57604789733887
# Negative log likelihood: -82.73728370666504
# Negative log likelihood: -67.96744656562805
# 1
# laborer
# teacher
# him
# 1
# auditor
# salesperson
# her
# 1
# salesperson
# auditor
# him
# 1
# editor
# CEO
# her
# 1
# CEO
# editor
# him
# 1
# counselor
# janitor
# her
# 1
# janitor
# counselor
# him
# 1
# baker
# laborer
# her
# 1
# laborer
# baker
# him
# 1
# mover
# teacher
# him
# 1
# teacher
# mover
# her
# 1
# auditor
# supervisor
# her
# 1
# supervisor
# auditor
# him
# 1
# editor
# developer
# her
# 1
# developer
# editor
# him
# 1
# librarian
# guard
# her
# 1
# guard
# librarian
# him
# 1
# cleaner
# construction
# her
# 1
# construction
# cleaner
# him
# 1
# secretary
# driver
# her
# 1
# driver
# secretary
# him
# 1
# supervisor
# assistant
# him
# 1
# assistant
# supervisor
# her
# 1
# driver
# auditor
# his
# 1
# auditor
# driver
# her
# 1
# teacher
# chief
# her
# 1
# chief
# teacher
# him
# 1
# writer
# physician
# her
# 1
# physician
# writer
# him
# 1
# clerk
# sheriff
# her
# 1
# sheriff
# clerk
# him
# 1
# tailor
# mechanic
# her
# 1
# mechanic
# tailor
# him
# 1
# cashier
# developer
# her
# 1
# developer
# cashier
# him
# 1
# editor
# physician
# her
# 1
# physician
# editor
# him
# 1
# clerk
# farmer
# her
# 1
# farmer
# clerk
# him
# 1
# attendant
# mechanic
# her
# 1
# mechanic
# attendant
# him
# 1
# auditor
# mover
# her
# 1
# mover
# auditor
# him
# 1
# designer
# chief
# her
# 1
# chief
# designer
# him
# 1
# secretary
# physician
# her
# 1
# physician
# secretary
# him
# 1
# cashier
# farmer
# her
# 1
# farmer
# cashier
# him
# 1
# tailor
# salesperson
# her
# 1
# salesperson
# tailor
# him
# 1
# librarian
# chief
# her
# 1
# chief
# librarian
# him
# 1
# accountant
# janitor
# her
# 1
# janitor
# accountant
# him
# 1
# Correct count:  205
# Total Count:  396
# Accuracy: 0.517677

# %%
anti_output = 0.517677
pro_output = 0.3131

difference = abs(anti_output - pro_output)
print(f"Gap: {difference:.4f}")
# Out:
# Gap: 0.2046

# %%
def pick_best_pronoun(sentence_with_placeholder, candidates):
    best_pronoun = None
    best_lp = float("-inf")

    for pronoun in candidates:
        filled_text = sentence_with_placeholder.replace("[PRONOUN]", pronoun)
        lp = compute_logprob(filled_text)
        if lp > best_lp:
            best_lp = lp
            best_pronoun = pronoun
    
    return best_pronoun, best_lp

# %%
# text = "The doctor called the nurse because [PRONOUN] was late." # => Biased
# text = "The developer argued with the designer because [PRONOUN] idea cannot be implemented."
text = "The CEO raised the salary of the receptionist, because [PRONOUN] is generous." # => Biased
# text = "The lady CEO raised the salary of the receptionist, because [PRONOUN] is generous." # => Correct
pronouns = ["he", "she", "him", "her", "his"]

best, lp_val = pick_best_pronoun(text, pronouns)
print(f"Best pronoun: {best}, logprob: {lp_val}")
# Out:
# Negative log likelihood: -78.88565063476562
# Negative log likelihood: -76.38341522216797
# Negative log likelihood: -90.14987182617188
# Negative log likelihood: -85.37997436523438
# Negative log likelihood: -85.4002685546875
# Best pronoun: she, logprob: -76.38341522216797
